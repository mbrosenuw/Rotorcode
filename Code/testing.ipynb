# %%
import asymrotor
import matplotlib.pyplot as plt

ihod = [15.5, 0.0871, 0.0866]
uihod = [14.5, 0.0872, 0.0867]
asymrotor.spectra(ihod, uihod, [1,1,1],20,10,'ihoh', [-40,60], 0.05, False, stats = [1,1,1,1])
# Out:
# ...
# calculating spectra: 100%|██████████| 26460/26460 [00:04<00:00, 5381.24it/s]
# Elapsed time: 5.564414024353027 seconds

# %%
# Out:
# (-0.05, 0.3)
